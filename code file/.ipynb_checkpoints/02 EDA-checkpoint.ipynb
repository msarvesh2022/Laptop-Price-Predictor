# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
h= pd.read_csv('clean_laptop_dataset.csv')

# %%
pd.read_csv('clean_laptop_dataset.csv')

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Ram  Weight     Price  HD_display  \
# 0   Apple  Ultrabook    13.3    8    1.37   71379.0           0
# 1   Apple  Ultrabook    13.3    8    1.34   47896.0           0
# 2      HP   Notebook    15.6    8    1.86   30636.0           1
# 3   Apple  Ultrabook    15.4   16    1.83  135195.0           0
# 4   Apple  Ultrabook    13.3    8    1.37   96096.0           0
#
#        cpu_brand  memory gpu_brand operating_system
# 0  Intel Core i5   128.0     Intel            MacOS
# 1  Intel Core i5   128.0     Intel            MacOS
# 2  Intel Core i5   256.0     Intel            MacOS
# 3  Intel Core i7   512.0       AMD            MacOS
# 4  Intel Core i5   256.0     Intel            MacOS

# %%
sns.barplot(x= df.TypeName, y= df.Price)
plt.xticks(rotation=30)
plt.show()

# %%
df.Company.nunique()
# Out:
# 19

# %%
df.TypeName= df.TypeName.apply(lambda x: 'Notbook' if x=='Netbook' else x)

# %%
df.TypeName= df.TypeName.apply(lambda x: 'Notebook' if x=='Notbook' else x)

# %%
sns.barplot(x= df.TypeName, y= df.Price)
plt.xticks(rotation=30)
plt.show()

# %%
df.TypeName.value_counts()
# Out:
# TypeName
# Notebook              752
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Name: count, dtype: int64

# %%
h= df.head()

# %%
h
# Out:
#   Company   TypeName  Inches  Ram  Weight     Price  HD_display  \
# 0   Apple  Ultrabook    13.3    8    1.37   71379.0           0
# 1   Apple  Ultrabook    13.3    8    1.34   47896.0           0
# 2      HP   Notebook    15.6    8    1.86   30636.0           1
# 3   Apple  Ultrabook    15.4   16    1.83  135195.0           0
# 4   Apple  Ultrabook    13.3    8    1.37   96096.0           0
#
#        cpu_brand  memory gpu_brand operating_system
# 0  Intel Core i5   128.0     Intel            MacOS
# 1  Intel Core i5   128.0     Intel            MacOS
# 2  Intel Core i5   256.0     Intel            MacOS
# 3  Intel Core i7   512.0       AMD            MacOS
# 4  Intel Core i5   256.0     Intel            MacOS

# %%
df.TypeName.value_counts()
# Out:
# TypeName
# Notebook              752
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Name: count, dtype: int64

# %%
sns.countplot(x= df.TypeName)
plt.xticks(rotation=30)
plt.show()

# %%
sns.barplot(x= df.TypeName, y= df.Price, hue=df.HD_display)
plt.xticks(rotation=30)
plt.show()

# %%
sns.histplot(df.Price, kde= True, bins=15)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.scatterplot(x= df.TypeName, y= df.Price)
plt.xticks(rotation=30)
plt.show()

# %%
h
# Out:
#   Company   TypeName  Inches  Ram  Weight     Price  HD_display  \
# 0   Apple  Ultrabook    13.3    8    1.37   71379.0           0
# 1   Apple  Ultrabook    13.3    8    1.34   47896.0           0
# 2      HP   Notebook    15.6    8    1.86   30636.0           1
# 3   Apple  Ultrabook    15.4   16    1.83  135195.0           0
# 4   Apple  Ultrabook    13.3    8    1.37   96096.0           0
#
#        cpu_brand  memory gpu_brand operating_system
# 0  Intel Core i5   128.0     Intel            MacOS
# 1  Intel Core i5   128.0     Intel            MacOS
# 2  Intel Core i5   256.0     Intel            MacOS
# 3  Intel Core i7   512.0       AMD            MacOS
# 4  Intel Core i5   256.0     Intel            MacOS

# %% [markdown]
# ## Inches

# %%
df.Inches.value_counts()
# Out:
# Inches
# 15.6    665
# 14.0    197
# 13.3    164
# 17.3    164
# 12.5     39
# 11.6     33
# 12.0      6
# 13.5      6
# 13.9      6
# 12.3      5
# 10.1      4
# 15.4      4
# 15.0      4
# 13.0      2
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# Name: count, dtype: int64

# %%
sns.boxplot(x= df.Inches)
# Out:
# <Axes: xlabel='Inches'>

# %%
df.Inches.describe()
# Out:
# count    1303.000000
# mean       15.017191
# std         1.426304
# min        10.100000
# 25%        14.000000
# 50%        15.600000
# 75%        15.600000
# max        18.400000
# Name: Inches, dtype: float64

# %%
sns.kdeplot(df.Inches)
# Out:
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
# fig ax= plt.subplots(1,2)
# sns.scatterplot(x= df.Inches, y = df.Price, ax= ax[0])
# sns.scatterplot(x= df.Company, y = df.Price, ax= ax[1])
# plt.show()

# %%
sns.barplot(x= df.Inches, y= df.Price)
plt.xticks(rotation=30)
plt.show()

# %%
sns.countplot(x= df.Inches)
plt.xticks(rotation=30)
plt.show()

# %%
h
# Out:
#   Company   TypeName  Inches  Ram  Weight     Price  HD_display  \
# 0   Apple  Ultrabook    13.3    8    1.37   71379.0           0
# 1   Apple  Ultrabook    13.3    8    1.34   47896.0           0
# 2      HP   Notebook    15.6    8    1.86   30636.0           1
# 3   Apple  Ultrabook    15.4   16    1.83  135195.0           0
# 4   Apple  Ultrabook    13.3    8    1.37   96096.0           0
#
#        cpu_brand  memory gpu_brand operating_system
# 0  Intel Core i5   128.0     Intel            MacOS
# 1  Intel Core i5   128.0     Intel            MacOS
# 2  Intel Core i5   256.0     Intel            MacOS
# 3  Intel Core i7   512.0       AMD            MacOS
# 4  Intel Core i5   256.0     Intel            MacOS

# %%
sns.barplot(x= df.TypeName, y= df.Inches)
plt.xticks(rotation=30)
plt.show()

# %%
h
# Out:
#   Company   TypeName  Inches  Ram  Weight     Price  HD_display  \
# 0   Apple  Ultrabook    13.3    8    1.37   71379.0           0
# 1   Apple  Ultrabook    13.3    8    1.34   47896.0           0
# 2      HP   Notebook    15.6    8    1.86   30636.0           1
# 3   Apple  Ultrabook    15.4   16    1.83  135195.0           0
# 4   Apple  Ultrabook    13.3    8    1.37   96096.0           0
#
#        cpu_brand  memory gpu_brand operating_system
# 0  Intel Core i5   128.0     Intel            MacOS
# 1  Intel Core i5   128.0     Intel            MacOS
# 2  Intel Core i5   256.0     Intel            MacOS
# 3  Intel Core i7   512.0       AMD            MacOS
# 4  Intel Core i5   256.0     Intel            MacOS

# %% [markdown]
# ### RAM

# %%
sns.countplot(x= df.Ram)
# Out:
# <Axes: xlabel='Ram', ylabel='count'>

# %%
df.Ram.dtype
# Out:
# dtype('int64')

# %%
sns.kdeplot(x= df.Ram)
# Out:
# <Axes: xlabel='Ram', ylabel='Density'>

# %%
sns.barplot(x= df.Ram,y= df.Price)
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
sns.scatterplot(x= df.Ram,y= df.Price)
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
df.Ram.value_counts()
# Out:
# Ram
# 8     619
# 4     375
# 16    200
# 6      41
# 12     25
# 2      22
# 32     17
# 24      3
# 64      1
# Name: count, dtype: int64

# %%
df[df.Ram==64]
# Out:
#      Company TypeName  Inches  Ram  Weight     Price  HD_display  \
# 1066    Asus   Gaming    17.3   64    3.58  211788.0           1
#
#           cpu_brand  memory gpu_brand operating_system
# 1066  Intel Core i7  1000.0    Nvidia          Windows

# %%
df.gpu_brand.value_counts()
# Out:
# gpu_brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
sns.barplot(x= df.Ram,y= df.Inches)
# Out:
# <Axes: xlabel='Ram', ylabel='Inches'>

# %%
sns.scatterplot(x= df.Ram,y= df.Inches)
# Out:
# <Axes: xlabel='Ram', ylabel='Inches'>
