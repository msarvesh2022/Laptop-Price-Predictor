# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('clean_laptop_dataset.csv')

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Ram  Weight     Price  HD_display  \
# 0   Apple  Ultrabook    13.3    8    1.37   71379.0           0
# 1   Apple  Ultrabook    13.3    8    1.34   47896.0           0
# 2      HP   Notebook    15.6    8    1.86   30636.0           1
# 3   Apple  Ultrabook    15.4   16    1.83  135195.0           0
# 4   Apple  Ultrabook    13.3    8    1.37   96096.0           0
#
#        cpu_brand  memory gpu_brand operating_system
# 0  Intel Core i5   128.0     Intel            MacOS
# 1  Intel Core i5   128.0     Intel            MacOS
# 2  Intel Core i5   256.0     Intel            MacOS
# 3  Intel Core i7   512.0       AMD            MacOS
# 4  Intel Core i5   256.0     Intel            MacOS

# %%
h = df.head()

# %% [markdown]
# ## feature engineering

# %%
df.shape
# Out:
# (1303, 11)

# %%
df.dtypes
# Out:
# Company              object
# TypeName             object
# Inches              float64
# Ram                   int64
# Weight              float64
# Price               float64
# HD_display            int64
# cpu_brand            object
# memory              float64
# gpu_brand            object
# operating_system     object
# dtype: object

# %% [markdown]
# ## Null values

# %%
df.isnull().mean()
# Out:
# Company             0.0
# TypeName            0.0
# Inches              0.0
# Ram                 0.0
# Weight              0.0
# Price               0.0
# HD_display          0.0
# cpu_brand           0.0
# memory              0.0
# gpu_brand           0.0
# operating_system    0.0
# dtype: float64

# %% [markdown]
# #### No null values found

# %%
# Out:
# Index(['Company', 'TypeName', 'Inches', 'Ram', 'Weight', 'Price', 'HD_display',
#        'cpu_brand', 'memory', 'gpu_brand', 'operating_system'],
#       dtype='object')

# %%
df = df[['Company', 'TypeName', 'Inches', 'Ram', 'Weight',  'HD_display',
       'cpu_brand', 'memory', 'gpu_brand', 'operating_system', 'Price']]

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Ram  Weight  HD_display      cpu_brand  memory  \
# 0   Apple  Ultrabook    13.3    8    1.37           0  Intel Core i5   128.0
# 1   Apple  Ultrabook    13.3    8    1.34           0  Intel Core i5   128.0
# 2      HP   Notebook    15.6    8    1.86           1  Intel Core i5   256.0
# 3   Apple  Ultrabook    15.4   16    1.83           0  Intel Core i7   512.0
# 4   Apple  Ultrabook    13.3    8    1.37           0  Intel Core i5   256.0
#
#   gpu_brand operating_system     Price
# 0     Intel            MacOS   71379.0
# 1     Intel            MacOS   47896.0
# 2     Intel            MacOS   30636.0
# 3       AMD            MacOS  135195.0
# 4     Intel            MacOS   96096.0

# %%
X= df.iloc[:,0:10]
y= df.iloc[:,-1]

# %%
X
# Out:
#      Company            TypeName  Inches  Ram  Weight  HD_display  \
# 0      Apple           Ultrabook    13.3    8    1.37           0
# 1      Apple           Ultrabook    13.3    8    1.34           0
# 2         HP            Notebook    15.6    8    1.86           1
# 3      Apple           Ultrabook    15.4   16    1.83           0
# 4      Apple           Ultrabook    13.3    8    1.37           0
# ...      ...                 ...     ...  ...     ...         ...
# 1298  Lenovo  2 in 1 Convertible    14.0    4    1.80           1
# 1299  Lenovo  2 in 1 Convertible    13.3   16    1.30           1
# 1300  Lenovo            Notebook    14.0    2    1.50           0
# 1301      HP            Notebook    15.6    6    2.19           0
# 1302    Asus            Notebook    15.6    4    2.20           0
#
#                   cpu_brand  memory gpu_brand operating_system
# 0             Intel Core i5   128.0     Intel            MacOS
# 1             Intel Core i5   128.0     Intel            MacOS
# 2             Intel Core i5   256.0     Intel            MacOS
# 3             Intel Core i7   512.0       AMD            MacOS
# 4             Intel Core i5   256.0     Intel            MacOS
# ...                     ...     ...       ...              ...
# 1298          Intel Core i7   128.0     Intel          Windows
# 1299          Intel Core i7   512.0     Intel          Windows
# 1300  Other Intel processor    64.0     Intel          Windows
# 1301          Intel Core i7  1000.0       AMD          Windows
# 1302  Other Intel processor   500.0     Intel          Windows
#
# [1303 rows x 10 columns]

# %%
y
# Out:
# 0        71379.0
# 1        47896.0
# 2        30636.0
# 3       135195.0
# 4        96096.0
#           ...
# 1298     33993.0
# 1299     79867.0
# 1300     12201.0
# 1301     40706.0
# 1302     19660.0
# Name: Price, Length: 1303, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#       Company   TypeName  Inches  Ram  Weight  HD_display      cpu_brand  \
# 810        HP     Gaming    17.3   12    3.74           1  Intel Core i7
# 948      Dell   Notebook    17.3    4    2.36           0  Intel Core i3
# 742   Toshiba   Notebook    14.0    8    1.25           1  Intel Core i5
# 631      Dell     Gaming    15.6   16    2.62           1  Intel Core i7
# 834    Lenovo   Notebook    14.0    8    1.32           1  Intel Core i5
# ...       ...        ...     ...  ...     ...         ...            ...
# 753    Lenovo  Ultrabook    14.0    4    1.70           1  Intel Core i5
# 1155       HP   Notebook    15.6    4    1.91           1            AMD
# 351        HP   Notebook    15.6    8    1.84           1  Intel Core i7
# 1167   Lenovo   Notebook    15.6    4    2.20           1  Intel Core i3
# 851      Asus     Gaming    15.6   16    2.10           1  Intel Core i7
#
#       memory gpu_brand operating_system
# 810   1000.0       AMD          Windows
# 948   1000.0       AMD          Windows
# 742    256.0     Intel          Windows
# 631    256.0    Nvidia          Windows
# 834    256.0     Intel          Windows
# ...      ...       ...              ...
# 753    180.0     Intel          Windows
# 1155   256.0       AMD          Windows
# 351    256.0     Intel          Windows
# 1167  1000.0    Nvidia          Windows
# 851    128.0    Nvidia          Windows
#
# [1042 rows x 10 columns]

# %% [markdown]
# ## Scaling of Data

# %%
num_data= X_train.select_dtypes(exclude=['object'])
cat_data= X_train.select_dtypes(include=['object'])

# %%
num_data
# Out:
#       Inches  Ram  Weight  HD_display  memory
# 810     17.3   12    3.74           1  1000.0
# 948     17.3    4    2.36           0  1000.0
# 742     14.0    8    1.25           1   256.0
# 631     15.6   16    2.62           1   256.0
# 834     14.0    8    1.32           1   256.0
# ...      ...  ...     ...         ...     ...
# 753     14.0    4    1.70           1   180.0
# 1155    15.6    4    1.91           1   256.0
# 351     15.6    8    1.84           1   256.0
# 1167    15.6    4    2.20           1  1000.0
# 851     15.6   16    2.10           1   128.0
#
# [1042 rows x 5 columns]

# %%
cat_data
# Out:
#       Company   TypeName      cpu_brand gpu_brand operating_system
# 810        HP     Gaming  Intel Core i7       AMD          Windows
# 948      Dell   Notebook  Intel Core i3       AMD          Windows
# 742   Toshiba   Notebook  Intel Core i5     Intel          Windows
# 631      Dell     Gaming  Intel Core i7    Nvidia          Windows
# 834    Lenovo   Notebook  Intel Core i5     Intel          Windows
# ...       ...        ...            ...       ...              ...
# 753    Lenovo  Ultrabook  Intel Core i5     Intel          Windows
# 1155       HP   Notebook            AMD       AMD          Windows
# 351        HP   Notebook  Intel Core i7     Intel          Windows
# 1167   Lenovo   Notebook  Intel Core i3    Nvidia          Windows
# 851      Asus     Gaming  Intel Core i7    Nvidia          Windows
#
# [1042 rows x 5 columns]

# %% [markdown]
# ### StanderScaler

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()

# %%
scaler.fit(num_data)
# Out:
# StandardScaler()

# %%
X_train_scaled= scaler.transform(num_data)

# %%
X_train_scaled
# Out:
# array([[ 1.62156794,  0.72145578,  2.56338245,  0.64181315,  1.55755529],
#        [ 1.62156794, -0.85455454,  0.47958051, -1.55808587,  1.55755529],
#        [-0.72451003, -0.06654938, -1.19652106,  0.64181315, -0.50233922],
#        ...,
#        [ 0.41298232, -0.06654938, -0.30562023,  0.64181315, -0.50233922],
#        [ 0.41298232, -0.85455454,  0.23798028,  0.64181315,  1.55755529],
#        [ 0.41298232,  1.50946095,  0.08698014,  0.64181315, -0.85672967]])

# %%
X_train_scaled.shape
# Out:
# (1042, 5)

# %%
num_data.shape
# Out:
# (1042, 5)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=num_data.columns)

# %%
X_train_scaled
# Out:
#         Inches       Ram    Weight  HD_display    memory
# 0     1.621568  0.721456  2.563382    0.641813  1.557555
# 1     1.621568 -0.854555  0.479581   -1.558086  1.557555
# 2    -0.724510 -0.066549 -1.196521    0.641813 -0.502339
# 3     0.412982  1.509461  0.872181    0.641813 -0.502339
# 4    -0.724510 -0.066549 -1.090821    0.641813 -0.502339
# ...        ...       ...       ...         ...       ...
# 1037 -0.724510 -0.854555 -0.517020    0.641813 -0.712759
# 1038  0.412982 -0.854555 -0.199920    0.641813 -0.502339
# 1039  0.412982 -0.066549 -0.305620    0.641813 -0.502339
# 1040  0.412982 -0.854555  0.237980    0.641813  1.557555
# 1041  0.412982  1.509461  0.086980    0.641813 -0.856730
#
# [1042 rows x 5 columns]

# %%
sns.histplot(X_train_scaled.Ram)
# Out:
# <Axes: xlabel='Ram', ylabel='Count'>

# %%
np.round(X_train_scaled,1).head()
# Out:
#    Inches  Ram  Weight  HD_display  memory
# 0     1.6  0.7     2.6         0.6     1.6
# 1     1.6 -0.9     0.5        -1.6     1.6
# 2    -0.7 -0.1    -1.2         0.6    -0.5
# 3     0.4  1.5     0.9         0.6    -0.5
# 4    -0.7 -0.1    -1.1         0.6    -0.5

# %%
num_data
# Out:
#       Inches  Ram  Weight  HD_display  memory
# 810     17.3   12    3.74           1  1000.0
# 948     17.3    4    2.36           0  1000.0
# 742     14.0    8    1.25           1   256.0
# 631     15.6   16    2.62           1   256.0
# 834     14.0    8    1.32           1   256.0
# ...      ...  ...     ...         ...     ...
# 753     14.0    4    1.70           1   180.0
# 1155    15.6    4    1.91           1   256.0
# 351     15.6    8    1.84           1   256.0
# 1167    15.6    4    2.20           1  1000.0
# 851     15.6   16    2.10           1   128.0
#
# [1042 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
cat_data.head()
# Out:
#      Company  TypeName      cpu_brand gpu_brand operating_system
# 810       HP    Gaming  Intel Core i7       AMD          Windows
# 948     Dell  Notebook  Intel Core i3       AMD          Windows
# 742  Toshiba  Notebook  Intel Core i5     Intel          Windows
# 631     Dell    Gaming  Intel Core i7    Nvidia          Windows
# 834   Lenovo  Notebook  Intel Core i5     Intel          Windows

# %%
ecd= LabelEncoder()
