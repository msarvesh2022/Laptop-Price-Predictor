# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('clean_laptop_dataset.csv')

# %% [markdown]
# ## Building the working ML model with the help of pipeline

# %%
df
# Out:
#      Company            TypeName  Inches  Ram  Weight  HD_display  \
# 0      Apple           Ultrabook    13.3    8    1.37           0
# 1      Apple           Ultrabook    13.3    8    1.34           0
# 2         HP            Notebook    15.6    8    1.86           1
# 3      Apple           Ultrabook    15.4   16    1.83           0
# 4      Apple           Ultrabook    13.3    8    1.37           0
# ...      ...                 ...     ...  ...     ...         ...
# 1298  Lenovo  2 in 1 Convertible    14.0    4    1.80           1
# 1299  Lenovo  2 in 1 Convertible    13.3   16    1.30           1
# 1300  Lenovo            Notebook    14.0    2    1.50           0
# 1301      HP            Notebook    15.6    6    2.19           0
# 1302    Asus            Notebook    15.6    4    2.20           0
#
#                   cpu_brand  memory gpu_brand operating_system     Price
# 0             Intel Core i5   128.0     Intel            MacOS   71379.0
# 1             Intel Core i5   128.0     Intel            MacOS   47896.0
# 2             Intel Core i5   256.0     Intel            MacOS   30636.0
# 3             Intel Core i7   512.0       AMD            MacOS  135195.0
# 4             Intel Core i5   256.0     Intel            MacOS   96096.0
# ...                     ...     ...       ...              ...       ...
# 1298          Intel Core i7   128.0     Intel          Windows   33993.0
# 1299          Intel Core i7   512.0     Intel          Windows   79867.0
# 1300  Other Intel processor    64.0     Intel          Windows   12201.0
# 1301          Intel Core i7  1000.0       AMD          Windows   40706.0
# 1302  Other Intel processor   500.0     Intel          Windows   19660.0
#
# [1303 rows x 11 columns]

# %%
X= df.iloc[:,:10]
y= df.iloc[:,-1]

# %%
X.head()
# Out:
#   Company   TypeName  Inches  Ram  Weight  HD_display      cpu_brand  memory  \
# 0   Apple  Ultrabook    13.3    8    1.37           0  Intel Core i5   128.0
# 1   Apple  Ultrabook    13.3    8    1.34           0  Intel Core i5   128.0
# 2      HP   Notebook    15.6    8    1.86           1  Intel Core i5   256.0
# 3   Apple  Ultrabook    15.4   16    1.83           0  Intel Core i7   512.0
# 4   Apple  Ultrabook    13.3    8    1.37           0  Intel Core i5   256.0
#
#   gpu_brand operating_system
# 0     Intel            MacOS
# 1     Intel            MacOS
# 2     Intel            MacOS
# 3       AMD            MacOS
# 4     Intel            MacOS

# %%
y.head()
# Out:
# 0     71379.0
# 1     47896.0
# 2     30636.0
# 3    135195.0
# 4     96096.0
# Name: Price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,y, test_size=0.2)

# %%
X_train
# Out:
#      Company   TypeName  Inches  Ram  Weight  HD_display  \
# 982   Lenovo   Notebook    15.6    6    2.20           1
# 33      Dell  Ultrabook    13.3   16    1.20           1
# 566     Dell   Notebook    15.6    4    1.93           0
# 166     Acer   Notebook    15.6    4    2.10           0
# 1066    Asus     Gaming    17.3   64    3.58           1
# ...      ...        ...     ...  ...     ...         ...
# 1077     MSI     Gaming    17.3   16    3.78           1
# 1256    Asus     Gaming    17.3   16    4.00           1
# 634     Asus   Notebook    15.6    8    2.00           0
# 732       HP   Notebook    15.6    6    2.10           1
# 1272  Lenovo   Notebook    14.0    2    1.50           0
#
#                   cpu_brand  memory gpu_brand operating_system
# 982                     AMD   256.0       AMD          Windows
# 33            Intel Core i7   512.0     Intel          Windows
# 566           Intel Core i5   500.0     Intel          Windows
# 166   Other Intel processor  1000.0     Intel          Windows
# 1066          Intel Core i7  1000.0    Nvidia          Windows
# ...                     ...     ...       ...              ...
# 1077          Intel Core i7   256.0    Nvidia          Windows
# 1256          Intel Core i7   128.0    Nvidia          Windows
# 634   Other Intel processor  1000.0     Intel          Windows
# 732                     AMD   128.0       AMD          Windows
# 1272  Other Intel processor    64.0     Intel          Windows
#
# [1042 rows x 10 columns]

# %%
log_pipe = Pipeline([('step1',step1),
                     ('step2',step2)
                    ])
